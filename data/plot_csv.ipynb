# %%
# Loaded variable 'df' from URI: /vlt/devel/graphics/textualize/projects/sparkline/data/short.csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/vlt/devel/graphics/textualize/projects/sparkline/data/fullround.csv')

# %%
plt.plot(df)

# %%
df.index.name = 'time in seconds'
df.columns.name = 'speed'
df.index
df.columns = ['speed']
df['speed']
plt.plot(df)
plt.xlabel(df.index.name)
plt.ylabel(df.columns[0])
# Out:
# RangeIndex(start=0, stop=437, step=1, name='time in seconds')
# time in seconds
# 0       0.69
# 1       3.58
# 2       6.89
# 3       8.88
# 4      10.78
#        ...
# 432     7.36
# 433     5.91
# 434     3.99
# 435     1.76
# 436     0.33
# Name: speed, Length: 437, dtype: float64
# Text(0.5, 0, 'time in seconds')
# Text(0, 0.5, 'speed')

# %%
df.to_csv(r'/vlt/devel/graphics/textualize/projects/sparkline/data/long.csv')
